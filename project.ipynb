# %% [markdown]
# # DX 704 Week 9 Project
#
# This week's project will build an email spam classifier based on the Enron email data set.
# You will perform your own feature extraction, and use naive Bayes to estimate the probability that a particular email is spam or not.
# Finally, you will review the tradeoffs from different thresholds for automatically sending emails to the junk folder.

# %% [markdown]
# The full project description and a template notebook are available on GitHub: [Project 9 Materials](https://github.com/bu-cds-dx704/dx704-project-09).

# %% [markdown]
# ## Example Code
#
# You may find it helpful to refer to these GitHub repositories of Jupyter notebooks for example code.
#
# * https://github.com/bu-cds-omds/dx601-examples
# * https://github.com/bu-cds-omds/dx602-examples
# * https://github.com/bu-cds-omds/dx603-examples
# * https://github.com/bu-cds-omds/dx704-examples
#
# Any calculations demonstrated in code examples or videos may be found in these notebooks, and you are allowed to copy this example code in your homework answers.

# %% [markdown]
# ## Part 1: Download Data Set
#
# We will be using the Enron spam data set as prepared in this GitHub repository.
#
# https://github.com/MWiechmann/enron_spam_data
#
# You may need to download this differently depending on your environment.

# %%
# !wget https://github.com/MWiechmann/enron_spam_data/raw/refs/heads/master/enron_spam_data.zip
# Out:
# --2025-11-03 04:07:25--  https://github.com/MWiechmann/enron_spam_data/raw/refs/heads/master/enron_spam_data.zip
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/MWiechmann/enron_spam_data/refs/heads/master/enron_spam_data.zip [following]
# --2025-11-03 04:07:25--  https://raw.githubusercontent.com/MWiechmann/enron_spam_data/refs/heads/master/enron_spam_data.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15642124 (15M) [application/zip]
# Saving to: ‘enron_spam_data.zip’
#
# enron_spam_data.zip 100%[===================>]  14.92M  58.1MB/s    in 0.3s
#
# 2025-11-03 04:07:26 (58.1 MB/s) - ‘enron_spam_data.zip’ saved [15642124/15642124]

# %%
import pandas as pd

# %%
# pandas can read the zip file directly
enron_spam_data = pd.read_csv("enron_spam_data.zip")
enron_spam_data
# Out:
#        Message ID                                            Subject  \
# 0               0                       christmas tree farm pictures
# 1               1                           vastar resources , inc .
# 2               2                       calpine daily gas nomination
# 3               3                                         re : issue
# 4               4                          meter 7268 nov allocation
# ...           ...                                                ...
# 33711       33711  = ? iso - 8859 - 1 ? q ? good _ news _ c = eda...
# 33712       33712  all prescript medicines are on special . to be...
# 33713       33713              the next generation online pharmacy .
# 33714       33714                     bloow in 5 - 10 times the time
# 33715       33715                   dear sir , i am interested in it
#
#                                                  Message Spam/Ham        Date
# 0                                                    NaN      ham  1999-12-10
# 1      gary , production from the high island larger ...      ham  1999-12-13
# 2                 - calpine daily gas nomination 1 . doc      ham  1999-12-14
# 3      fyi - see note below - already done .\nstella\...      ham  1999-12-14
# 4      fyi .\n- - - - - - - - - - - - - - - - - - - -...      ham  1999-12-14
# ...                                                  ...      ...         ...
# 33711  hello , welcome to gigapharm onlinne shop .\np...     spam  2005-07-29
# 33712  i got it earlier than expected and it was wrap...     spam  2005-07-29
# 33713  are you ready to rock on ? let the man in you ...     spam  2005-07-30
# 33714  learn how to last 5 - 10 times longer in\nbed ...     spam  2005-07-30
# 33715  hi : )\ndo you need some softwares ? i can giv...     spam  2005-07-31
#
# [33716 rows x 5 columns]

# %%
(enron_spam_data["Spam/Ham"] == "spam").mean()
# Out:
# np.float64(0.5092834262664611)

# %%
enron_spam_data.head()
# Out:
#    Message ID                       Subject  \
# 0           0  christmas tree farm pictures
# 1           1      vastar resources , inc .
# 2           2  calpine daily gas nomination
# 3           3                    re : issue
# 4           4     meter 7268 nov allocation
#
#                                              Message Spam/Ham        Date
# 0                                                NaN      ham  1999-12-10
# 1  gary , production from the high island larger ...      ham  1999-12-13
# 2             - calpine daily gas nomination 1 . doc      ham  1999-12-14
# 3  fyi - see note below - already done .\nstella\...      ham  1999-12-14
# 4  fyi .\n- - - - - - - - - - - - - - - - - - - -...      ham  1999-12-14

# %% [markdown]
# ## Part 2: Design a Feature Extractor
#
# Design a feature extractor for this data set and write out two files of features based on the text.
# Don't forget that both the Subject and Message columns are relevant sources of text data.
# For each email, you should count the number of repetitions of each feature present.
# The auto-grader will assume that you are using a multinomial distribution in the following problems.

# %%
# YOUR CHANGES HERE

import re
import json
import pandas as pd

# Assuming your DataFrame is named enron_spam_data
# Combine subject and message text, lowercase, and handle missing values
enron_spam_data["text"] = (
    enron_spam_data["Subject"].fillna("") + " " + enron_spam_data["Message"].fillna("")
).str.lower()

# Tokenize: extract only alphabetic words
def tokenize(text):
    return re.findall(r"[a-z]+", text)

# Count word frequencies for each email
from collections import Counter
enron_spam_data["features_json"] = enron_spam_data["text"].apply(
    lambda t: json.dumps(Counter(tokenize(t)))
)

# Split into train and test sets
train = enron_spam_data[enron_spam_data["Message ID"] % 30 != 0][
    ["Message ID", "features_json"]
]
test = enron_spam_data[enron_spam_data["Message ID"] % 30 == 0][
    ["Message ID", "features_json"]
]

# Save as TSV
train.to_csv("train-features.tsv", sep="\t", index=False)
test.to_csv("test-features.tsv", sep="\t", index=False)

# %% [markdown]
# Assign a row to the test data set if `Message ID % 30 == 0` and assign it to the training data set otherwise.
# Write two files, "train-features.tsv" and "test-features.tsv" with two columns, Message ID and features_json.
# The features_json column should contain a JSON dictionary where the keys are your feature names and the values are integer feature values.
# This will give us a sparse feature representation.

# %%
# YOUR CHANGES HERE

...

# %% [markdown]
# Submit "train-features.tsv" and "test-features.tsv" in Gradescope.

# %% [markdown]
# Hint: these features will be graded based on the test accuracy of a logistic regression based on the training features.
# This is to make sure that your feature set is not degenerate; you do not need to compute this regression yourself.
# You can separately assess your feature quality based on your results in part 6.

# %% [markdown]
# ## Part 3: Compute Conditional Probabilities
#
# Based on your training data, compute appropriate conditional probabilities for use with naïve Bayes.
# Use of additive smoothing with $\alpha=1$ to avoid zeros.

# %%
# YOUR CHANGES HERE

import pandas as pd
import json
from collections import Counter, defaultdict

# --- Load training features and labels
train = pd.read_csv("train-features.tsv", sep="\t")
labels = enron_spam_data[["Message ID", "Spam/Ham"]]  # original labels
train = train.merge(labels, on="Message ID", how="left")

# --- Accumulate word counts per class
ham_counts = Counter()
spam_counts = Counter()

for _, row in train.iterrows():
    feats = json.loads(row["features_json"])
    if row["Spam/Ham"] == "ham":
        ham_counts.update(feats)
    else:
        spam_counts.update(feats)

# --- Totals
total_ham_words = sum(ham_counts.values())
total_spam_words = sum(spam_counts.values())

# --- Vocabulary (unique features)
vocab = set(ham_counts.keys()) | set(spam_counts.keys())
V = len(vocab)
alpha = 1

# --- Compute smoothed probabilities
rows = []
for word in vocab:
    ham_prob = (ham_counts[word] + alpha) / (total_ham_words + alpha * V)
    spam_prob = (spam_counts[word] + alpha) / (total_spam_words + alpha * V)
    rows.append((word, ham_prob, spam_prob))

# --- Save results
feature_probs = pd.DataFrame(rows, columns=["feature", "ham_probability", "spam_probability"])
feature_probs.to_csv("feature-probabilities.tsv", sep="\t", index=False)

# %% [markdown]
# Save the conditional probabilities in a file "feature-probabilities.tsv" with columns feature, ham_probability and spam_probability.

# %%
# YOUR CHANGES HERE

...

# %% [markdown]
# Submit "feature-probabilities.tsv" in Gradescope.

# %% [markdown]
# ## Part 4: Implement a Naïve Bayes Classifier
#
# Implement a naïve Bayes classifier based on your previous feature probabilities.

# %%
# YOUR CHANGES HERE

import pandas as pd
import numpy as np
import json
from math import log, exp

# --- Load pieces we already have
train_feats = pd.read_csv("train-features.tsv", sep="\t")
feature_probs = pd.read_csv("feature-probabilities.tsv", sep="\t")

# Bring in labels from the original DataFrame
train_labeled = train_feats.merge(
    enron_spam_data[["Message ID", "Spam/Ham"]],
    on="Message ID",
    how="left"
)

# --- Build fast lookup dicts for P(word|class)
ham_lp = {}   # log P(word|ham)
spam_lp = {}  # log P(word|spam)
for _, r in feature_probs.iterrows():
    ham_lp[r["feature"]]  = np.log(r["ham_probability"])
    spam_lp[r["feature"]] = np.log(r["spam_probability"])

# --- Class priors from TRAINING messages
n_ham  = (train_labeled["Spam/Ham"] == "ham").sum()
n_spam = (train_labeled["Spam/Ham"] == "spam").sum()
n_tot  = len(train_labeled)

log_prior_ham  = np.log(n_ham / n_tot)
log_prior_spam = np.log(n_spam / n_tot)

# --- Naïve Bayes: log-likelihood per message
def logsumexp(a, b):
    """Two-term log-sum-exp for numerical stability."""
    m = max(a, b)
    return m + np.log(np.exp(a - m) + np.exp(b - m))

rows = []
for _, row in train_labeled.iterrows():
    feats = json.loads(row["features_json"])  # {token: count}

    # accumulate sum(count * log P(token|class))
    ll_ham  = 0.0
    ll_spam = 0.0
    for tok, cnt in feats.items():
        # Ignore tokens not in vocab (rare if features came from training set)
        if tok in ham_lp:  ll_ham  += cnt * ham_lp[tok]
        if tok in spam_lp: ll_spam += cnt * spam_lp[tok]

    # add log-priors
    logp_ham  = log_prior_ham  + ll_ham
    logp_spam = log_prior_spam + ll_spam

    # normalize to probabilities
    denom = logsumexp(logp_ham, logp_spam)
    p_ham  = np.exp(logp_ham  - denom)
    p_spam = np.exp(logp_spam - denom)

    rows.append((row["Message ID"], p_ham, p_spam))

train_preds = pd.DataFrame(rows, columns=["Message ID", "ham", "spam"])
train_preds.to_csv("train-predictions.tsv", sep="\t", index=False)

train_preds.head()
# Out:
#    Message ID  ham           spam
# 0           1  1.0  2.002591e-169
# 1           2  1.0   1.415146e-12
# 2           3  1.0  5.251134e-148
# 3           4  1.0  1.164033e-142
# 4           5  1.0   2.607868e-38

# %% [markdown]
# Save your prediction probabilities to "train-predictions.tsv" with columns Message ID, ham and spam.

# %%
# YOUR CHANGES HERE

...

# %% [markdown]
# Submit "train-predictions.tsv" in Gradescope.

# %% [markdown]
# ## Part 5: Predict Spam Probability for Test Data
#
# Use your previous classifier to predict spam probability for the test data.

# %%
# YOUR CHANGES HERE

import pandas as pd
import numpy as np
import json
from math import log, exp

# --- Load data and model pieces
test_feats = pd.read_csv("test-features.tsv", sep="\t")
feature_probs = pd.read_csv("feature-probabilities.tsv", sep="\t")

# Load priors from training data
train_labeled = pd.read_csv("train-features.tsv", sep="\t").merge(
    enron_spam_data[["Message ID", "Spam/Ham"]],
    on="Message ID",
    how="left"
)
n_ham  = (train_labeled["Spam/Ham"] == "ham").sum()
n_spam = (train_labeled["Spam/Ham"] == "spam").sum()
n_tot  = len(train_labeled)

log_prior_ham  = np.log(n_ham / n_tot)
log_prior_spam = np.log(n_spam / n_tot)

# --- Precompute log P(word|class)
ham_lp  = dict(zip(feature_probs["feature"], np.log(feature_probs["ham_probability"])))
spam_lp = dict(zip(feature_probs["feature"], np.log(feature_probs["spam_probability"])))

def logsumexp(a, b):
    m = max(a, b)
    return m + np.log(np.exp(a - m) + np.exp(b - m))

# --- Predict for each test message
rows = []
for _, row in test_feats.iterrows():
    feats = json.loads(row["features_json"])

    ll_ham  = 0.0
    ll_spam = 0.0
    for tok, cnt in feats.items():
        if tok in ham_lp:  ll_ham  += cnt * ham_lp[tok]
        if tok in spam_lp: ll_spam += cnt * spam_lp[tok]

    logp_ham  = log_prior_ham  + ll_ham
    logp_spam = log_prior_spam + ll_spam

    denom = logsumexp(logp_ham, logp_spam)
    p_ham  = np.exp(logp_ham  - denom)
    p_spam = np.exp(logp_spam - denom)

    rows.append((row["Message ID"], p_ham, p_spam))

# --- Save predictions
test_preds = pd.DataFrame(rows, columns=["Message ID", "ham", "spam"])
test_preds.to_csv("test-predictions.tsv", sep="\t", index=False)

test_preds.head()
# Out:
#    Message ID       ham           spam
# 0           0  0.058159   9.418412e-01
# 1          30  1.000000   1.718842e-79
# 2          60  1.000000   1.709360e-12
# 3          90  1.000000   7.266627e-33
# 4         120  1.000000  1.422680e-170

# %% [markdown]
# Save your prediction probabilities in "test-predictions.tsv" with the same columns as "train-predictions.tsv".

# %%
# YOUR CHANGES HERE

...

# %% [markdown]
# Submit "test-predictions.tsv" in Gradescope.

# %% [markdown]
# ## Part 6: Construct ROC Curve
#
# For every probability threshold from 0.01 to .99 in increments of 0.01, compute the false and true positive rates from the test data using the spam class for positives.
# That is, if the predicted spam probability is greater than or equal to the threshold, predict spam.

# %%
# YOUR CHANGES HERE

import pandas as pd
import numpy as np

# --- Load predictions and true labels
test_preds = pd.read_csv("test-predictions.tsv", sep="\t")
labels = enron_spam_data[["Message ID", "Spam/Ham"]]

# merge to get true labels for test data
test_labeled = test_preds.merge(labels, on="Message ID", how="left")

# ensure consistent label
test_labeled["is_spam"] = (test_labeled["Spam/Ham"] == "spam").astype(int)

# --- Compute ROC data
rows = []
thresholds = np.arange(0.01, 1.00, 0.01)

for t in thresholds:
    # predict spam if P(spam) >= threshold
    pred_spam = (test_labeled["spam"] >= t).astype(int)

    # confusion-matrix elements
    tp = ((pred_spam == 1) & (test_labeled["is_spam"] == 1)).sum()
    fp = ((pred_spam == 1) & (test_labeled["is_spam"] == 0)).sum()
    fn = ((pred_spam == 0) & (test_labeled["is_spam"] == 1)).sum()
    tn = ((pred_spam == 0) & (test_labeled["is_spam"] == 0)).sum()

    tpr = tp / (tp + fn) if (tp + fn) > 0 else 0.0   # True Positive Rate
    fpr = fp / (fp + tn) if (fp + tn) > 0 else 0.0   # False Positive Rate

    rows.append((t, fpr, tpr))

roc_df = pd.DataFrame(rows, columns=["threshold", "false_positive_rate", "true_positive_rate"])

# --- Save to file
roc_df.to_csv("roc.tsv", sep="\t", index=False)
roc_df.head()
# Out:
#    threshold  false_positive_rate  true_positive_rate
# 0       0.01             0.032609            0.996503
# 1       0.02             0.032609            0.996503
# 2       0.03             0.030797            0.996503
# 3       0.04             0.028986            0.996503
# 4       0.05             0.027174            0.994755

# %% [markdown]
# Save this data in a file "roc.tsv" with columns threshold, false_positive_rate and true_positive rate.

# %%
# YOUR CHANGES HERE

...

# %% [markdown]
# Submit "roc.tsv" in Gradescope.

# %% [markdown]
# ## Part 7: Signup for Gemini API Key
#
# Create a free Gemini API key at https://aistudio.google.com/app/api-keys.
# You will need to do this with a personal Google account - it will not work with your BU Google account.
# This will not incur any charges unless you configure billing information for the key.
#
# You will be asked to start a Gemini free trial for week 11.
# This will not incur any charges unless you exceed expected usage by an order of magnitude.

# %% [markdown]
# No submission needed.

# %% [markdown]
# ## Part 8: Code
#
# Please submit a Jupyter notebook that can reproduce all your calculations and recreate the previously submitted files.
# You do not need to provide code for data collection if you did that by manually.

# %% [markdown]
# ## Part 9: Acknowledgements
#
# If you discussed this assignment with anyone, please acknowledge them here.
# If you did this assignment completely on your own, simply write none below.
#
# If you used any libraries not mentioned in this module's content, please list them with a brief explanation what you used them for. If you did not use any other libraries, simply write none below.
#
# If you used any generative AI tools, please add links to your transcripts below, and any other information that you feel is necessary to comply with the generative AI policy. If you did not use any generative AI tools, simply write none below.
